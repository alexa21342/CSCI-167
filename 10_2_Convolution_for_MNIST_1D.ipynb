# %% [markdown]
# <a href="https://colab.research.google.com/github/alexa21342/CSCI-167/blob/CSCI-167-Assignments/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Alex Cortez CSCI 167 11/3/2025

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-9amajphn
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-9amajphn
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=844dfc4403a1144eaa969eff60a9001a65add8b36f86d74475b2bfe2d4f78753
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hco1x0e1/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
# model = nn.Sequential(
# nn.Flatten(),
# nn.Linear(40, 100),
# nn.ReLU(),
# nn.Linear(100, 100),
# nn.ReLU(),
# nn.Linear(100, 10))

model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.787549, train error 72.22,  val loss 1.805373, percent error 75.90
# Epoch     1, train loss 1.410395, train error 54.88,  val loss 1.422593, percent error 59.20
# Epoch     2, train loss 1.281474, train error 51.12,  val loss 1.304438, percent error 55.70
# Epoch     3, train loss 1.351820, train error 56.10,  val loss 1.393980, percent error 59.50
# Epoch     4, train loss 1.214800, train error 48.12,  val loss 1.249614, percent error 51.90
# Epoch     5, train loss 1.120904, train error 45.60,  val loss 1.162271, percent error 49.40
# Epoch     6, train loss 1.101423, train error 44.58,  val loss 1.138002, percent error 49.50
# Epoch     7, train loss 0.960391, train error 37.97,  val loss 1.001682, percent error 40.10
# Epoch     8, train loss 0.907723, train error 36.33,  val loss 0.941718, percent error 37.40
# Epoch     9, train loss 0.871491, train error 35.95,  val loss 0.916628, percent error 39.40
# Epoch    10, train loss 0.772168, train error 31.50,  val loss 0.834753, percent error 33.30
# Epoch    11, train loss 0.708584, train error 27.62,  val loss 0.785460, percent error 31.50
# Epoch    12, train loss 0.648004, train error 25.05,  val loss 0.724602, percent error 28.50
# Epoch    13, train loss 0.621763, train error 24.12,  val loss 0.698942, percent error 26.80
# Epoch    14, train loss 0.539708, train error 19.78,  val loss 0.621476, percent error 22.30
# Epoch    15, train loss 0.578713, train error 22.62,  val loss 0.703205, percent error 27.30
# Epoch    16, train loss 0.514073, train error 19.40,  val loss 0.595417, percent error 22.30
# Epoch    17, train loss 0.438674, train error 15.93,  val loss 0.561458, percent error 20.70
# Epoch    18, train loss 0.438050, train error 16.22,  val loss 0.564719, percent error 21.60
# Epoch    19, train loss 0.389683, train error 14.75,  val loss 0.554419, percent error 20.60
# Epoch    20, train loss 0.310916, train error 11.82,  val loss 0.448780, percent error 17.40
# Epoch    21, train loss 0.327157, train error 11.88,  val loss 0.441831, percent error 15.70
# Epoch    22, train loss 0.275289, train error 9.95,  val loss 0.448684, percent error 16.10
# Epoch    23, train loss 0.264082, train error 9.90,  val loss 0.430374, percent error 15.40
# Epoch    24, train loss 0.296042, train error 11.53,  val loss 0.465599, percent error 17.60
# Epoch    25, train loss 0.257715, train error 9.07,  val loss 0.417958, percent error 14.10
# Epoch    26, train loss 0.226488, train error 7.70,  val loss 0.410104, percent error 13.90
# Epoch    27, train loss 0.199313, train error 6.68,  val loss 0.368588, percent error 11.90
# Epoch    28, train loss 0.209685, train error 7.25,  val loss 0.419557, percent error 13.60
# Epoch    29, train loss 0.193253, train error 6.68,  val loss 0.395000, percent error 12.80
# Epoch    30, train loss 0.183405, train error 6.18,  val loss 0.388794, percent error 12.50
# Epoch    31, train loss 0.172500, train error 5.80,  val loss 0.385607, percent error 12.40
# Epoch    32, train loss 0.182339, train error 7.12,  val loss 0.414500, percent error 14.20
# Epoch    33, train loss 0.173271, train error 6.07,  val loss 0.411356, percent error 12.60
# Epoch    34, train loss 0.153660, train error 5.47,  val loss 0.395714, percent error 12.60
# Epoch    35, train loss 0.156731, train error 5.32,  val loss 0.396551, percent error 13.20
# Epoch    36, train loss 0.143286, train error 5.00,  val loss 0.398907, percent error 11.90
# Epoch    37, train loss 0.143003, train error 5.00,  val loss 0.415173, percent error 13.20
# Epoch    38, train loss 0.167575, train error 6.35,  val loss 0.449667, percent error 12.90
# Epoch    39, train loss 0.123447, train error 4.47,  val loss 0.410660, percent error 12.70
# Epoch    40, train loss 0.103238, train error 3.07,  val loss 0.376162, percent error 11.60
# Epoch    41, train loss 0.105162, train error 3.10,  val loss 0.404919, percent error 12.40
# Epoch    42, train loss 0.101915, train error 3.20,  val loss 0.385321, percent error 11.20
# Epoch    43, train loss 0.092617, train error 2.78,  val loss 0.405001, percent error 12.50
# Epoch    44, train loss 0.094010, train error 2.97,  val loss 0.399000, percent error 11.20
# Epoch    45, train loss 0.094181, train error 2.70,  val loss 0.403903, percent error 11.50
# Epoch    46, train loss 0.097782, train error 3.50,  val loss 0.417401, percent error 12.50
# Epoch    47, train loss 0.085617, train error 2.47,  val loss 0.409576, percent error 11.60
# Epoch    48, train loss 0.082335, train error 2.35,  val loss 0.408876, percent error 11.80
# Epoch    49, train loss 0.078576, train error 2.07,  val loss 0.414333, percent error 12.40
# Epoch    50, train loss 0.085139, train error 2.47,  val loss 0.433356, percent error 12.50
# Epoch    51, train loss 0.080830, train error 2.18,  val loss 0.400561, percent error 10.80
# Epoch    52, train loss 0.080353, train error 2.55,  val loss 0.418526, percent error 11.60
# Epoch    53, train loss 0.092781, train error 3.05,  val loss 0.447782, percent error 12.00
# Epoch    54, train loss 0.074288, train error 2.25,  val loss 0.433759, percent error 11.70
# Epoch    55, train loss 0.070398, train error 2.18,  val loss 0.421493, percent error 12.40
# Epoch    56, train loss 0.069113, train error 2.00,  val loss 0.432405, percent error 12.00
# Epoch    57, train loss 0.069605, train error 1.78,  val loss 0.435901, percent error 11.80
# Epoch    58, train loss 0.065807, train error 1.80,  val loss 0.443636, percent error 11.30
# Epoch    59, train loss 0.060077, train error 1.28,  val loss 0.440228, percent error 11.80
# Epoch    60, train loss 0.057867, train error 1.22,  val loss 0.447003, percent error 12.30
# Epoch    61, train loss 0.056118, train error 1.10,  val loss 0.439672, percent error 11.80
# Epoch    62, train loss 0.055942, train error 1.15,  val loss 0.446477, percent error 12.20
# Epoch    63, train loss 0.054182, train error 1.07,  val loss 0.437234, percent error 11.20
# Epoch    64, train loss 0.055356, train error 1.00,  val loss 0.451344, percent error 11.70
# Epoch    65, train loss 0.054013, train error 1.10,  val loss 0.455424, percent error 12.20
# Epoch    66, train loss 0.052934, train error 1.12,  val loss 0.449721, percent error 12.10
# Epoch    67, train loss 0.051175, train error 0.97,  val loss 0.456583, percent error 12.00
# Epoch    68, train loss 0.051904, train error 1.05,  val loss 0.451772, percent error 11.80
# Epoch    69, train loss 0.053499, train error 1.20,  val loss 0.462313, percent error 12.70
# Epoch    70, train loss 0.049529, train error 0.85,  val loss 0.455645, percent error 12.00
# Epoch    71, train loss 0.048113, train error 0.70,  val loss 0.463665, percent error 12.30
# Epoch    72, train loss 0.048021, train error 0.90,  val loss 0.458706, percent error 12.10
# Epoch    73, train loss 0.047478, train error 0.78,  val loss 0.463474, percent error 12.10
# Epoch    74, train loss 0.047062, train error 0.85,  val loss 0.463391, percent error 12.10
# Epoch    75, train loss 0.048935, train error 1.00,  val loss 0.480047, percent error 12.30
# Epoch    76, train loss 0.045600, train error 0.78,  val loss 0.459823, percent error 11.80
# Epoch    77, train loss 0.044848, train error 0.88,  val loss 0.467603, percent error 12.10
# Epoch    78, train loss 0.045572, train error 0.80,  val loss 0.479734, percent error 11.20
# Epoch    79, train loss 0.044282, train error 0.80,  val loss 0.479149, percent error 12.00
# Epoch    80, train loss 0.043141, train error 0.72,  val loss 0.471266, percent error 11.80
# Epoch    81, train loss 0.042725, train error 0.62,  val loss 0.477658, percent error 12.10
# Epoch    82, train loss 0.041981, train error 0.68,  val loss 0.474848, percent error 12.10
# Epoch    83, train loss 0.041674, train error 0.68,  val loss 0.476547, percent error 12.30
# Epoch    84, train loss 0.041245, train error 0.65,  val loss 0.474928, percent error 11.80
# Epoch    85, train loss 0.040848, train error 0.57,  val loss 0.480375, percent error 12.00
# Epoch    86, train loss 0.040579, train error 0.62,  val loss 0.475347, percent error 11.90
# Epoch    87, train loss 0.040688, train error 0.60,  val loss 0.476440, percent error 11.90
# Epoch    88, train loss 0.040219, train error 0.60,  val loss 0.483144, percent error 12.10
# Epoch    89, train loss 0.040006, train error 0.57,  val loss 0.483213, percent error 12.10
# Epoch    90, train loss 0.039718, train error 0.57,  val loss 0.483953, percent error 12.10
# Epoch    91, train loss 0.039686, train error 0.53,  val loss 0.483582, percent error 12.20
# Epoch    92, train loss 0.039576, train error 0.62,  val loss 0.484427, percent error 12.00
# Epoch    93, train loss 0.038930, train error 0.57,  val loss 0.487701, percent error 11.70
# Epoch    94, train loss 0.039526, train error 0.55,  val loss 0.482265, percent error 12.00
# Epoch    95, train loss 0.039166, train error 0.68,  val loss 0.492173, percent error 12.00
# Epoch    96, train loss 0.037984, train error 0.57,  val loss 0.489394, percent error 12.10
# Epoch    97, train loss 0.037907, train error 0.57,  val loss 0.487744, percent error 12.10
# Epoch    98, train loss 0.038529, train error 0.50,  val loss 0.490176, percent error 12.20
# Epoch    99, train loss 0.039454, train error 0.62,  val loss 0.498886, percent error 12.70
