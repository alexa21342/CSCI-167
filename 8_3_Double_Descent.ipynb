# %% [markdown]
# <a href="https://colab.research.google.com/github/alexa21342/CSCI-167/blob/CSCI-167-Assignments/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Alex Cortez CSCI 167 10/27/2025

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-riorrxhh
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-riorrxhh
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=9cc1e6ec1deeece24ad4166d5fffddbf0b2f3d0a8b781bbfbc5f138a76e92d12
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8012ill3/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# Answers:
#
# 1. Training error becomes zero around 80 hidden units because this is where the model has enough parameters to perfectly fit the training data. At smaller widths, the model is underparameterized and cannot capture all patterns, but around this point it reaches the interpolation threshold.
#
# 2. The first minimum in the test error occurs around 40–60 hidden units because smaller models generalize better before they become too flexible. They capture the main structure of the data without overfitting to noise.
#
# 3. The maximum in the test error happens around 80–120 hidden units because at this point the model has just enough capacity to fit the training data exactly, including noise, leading to overfitting and a temporary rise in test error before larger models recover and generalize better again.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.259474, train error 84.65,  test loss 2.252516, test error 85.95
# Epoch   100, train loss 1.858260, train error 70.00,  test loss 1.714679, test error 68.47
# Epoch   200, train loss 1.851333, train error 70.40,  test loss 1.699903, test error 68.57
# Epoch   300, train loss 1.847266, train error 69.82,  test loss 1.702244, test error 68.62
# Epoch   400, train loss 1.847030, train error 70.38,  test loss 1.705508, test error 67.82
# Epoch   500, train loss 1.844231, train error 69.47,  test loss 1.705240, test error 68.53
# Epoch   600, train loss 1.842618, train error 69.78,  test loss 1.707426, test error 68.10
# Epoch   700, train loss 1.846236, train error 69.78,  test loss 1.705336, test error 68.93
# Epoch   800, train loss 1.851209, train error 70.00,  test loss 1.716714, test error 69.05
# Epoch   900, train loss 1.840221, train error 70.10,  test loss 1.705116, test error 68.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.296578, train error 88.40,  test loss 2.304566, test error 88.80
# Epoch   100, train loss 1.771564, train error 65.57,  test loss 1.622527, test error 62.78
# Epoch   200, train loss 1.731308, train error 63.15,  test loss 1.577340, test error 60.83
# Epoch   300, train loss 1.723860, train error 63.12,  test loss 1.571046, test error 60.92
# Epoch   400, train loss 1.715834, train error 62.85,  test loss 1.573603, test error 60.85
# Epoch   500, train loss 1.704731, train error 62.62,  test loss 1.569037, test error 60.95
# Epoch   600, train loss 1.704276, train error 62.60,  test loss 1.565248, test error 60.62
# Epoch   700, train loss 1.703054, train error 62.42,  test loss 1.569961, test error 61.20
# Epoch   800, train loss 1.704082, train error 62.50,  test loss 1.572572, test error 61.53
# Epoch   900, train loss 1.703451, train error 62.67,  test loss 1.565606, test error 60.90
# Training model with   6 hidden variables
# Epoch     0, train loss 2.204308, train error 82.10,  test loss 2.181032, test error 81.88
# Epoch   100, train loss 1.626051, train error 57.60,  test loss 1.455869, test error 56.00
# Epoch   200, train loss 1.574956, train error 55.15,  test loss 1.413802, test error 52.70
# Epoch   300, train loss 1.565424, train error 55.08,  test loss 1.421928, test error 52.90
# Epoch   400, train loss 1.557317, train error 54.05,  test loss 1.421495, test error 52.88
# Epoch   500, train loss 1.552942, train error 54.25,  test loss 1.428231, test error 52.53
# Epoch   600, train loss 1.555677, train error 54.38,  test loss 1.430421, test error 53.65
# Epoch   700, train loss 1.563294, train error 55.05,  test loss 1.455395, test error 53.95
# Epoch   800, train loss 1.550419, train error 54.42,  test loss 1.432980, test error 53.00
# Epoch   900, train loss 1.552881, train error 54.45,  test loss 1.437341, test error 53.40
# Training model with   8 hidden variables
# Epoch     0, train loss 2.202898, train error 81.45,  test loss 2.181653, test error 79.75
# Epoch   100, train loss 1.618088, train error 58.22,  test loss 1.478558, test error 56.62
# Epoch   200, train loss 1.579358, train error 57.33,  test loss 1.452372, test error 55.40
# Epoch   300, train loss 1.563878, train error 56.53,  test loss 1.457028, test error 54.95
# Epoch   400, train loss 1.544961, train error 55.20,  test loss 1.462953, test error 55.28
# Epoch   500, train loss 1.535803, train error 55.42,  test loss 1.462995, test error 55.03
# Epoch   600, train loss 1.526258, train error 55.08,  test loss 1.456059, test error 54.50
# Epoch   700, train loss 1.522854, train error 55.05,  test loss 1.470565, test error 54.72
# Epoch   800, train loss 1.516564, train error 53.50,  test loss 1.475227, test error 55.33
# Epoch   900, train loss 1.518464, train error 53.67,  test loss 1.476509, test error 55.78
# Training model with  10 hidden variables
# Epoch     0, train loss 2.255841, train error 83.22,  test loss 2.251474, test error 83.47
# Epoch   100, train loss 1.581387, train error 55.22,  test loss 1.428493, test error 53.35
# Epoch   200, train loss 1.486901, train error 50.05,  test loss 1.353968, test error 50.40
# Epoch   300, train loss 1.431971, train error 48.00,  test loss 1.308529, test error 48.10
# Epoch   400, train loss 1.407981, train error 47.42,  test loss 1.322768, test error 48.97
# Epoch   500, train loss 1.394353, train error 47.60,  test loss 1.331614, test error 48.85
# Epoch   600, train loss 1.390242, train error 46.83,  test loss 1.348137, test error 49.47
# Epoch   700, train loss 1.378452, train error 47.38,  test loss 1.357038, test error 49.70
# Epoch   800, train loss 1.363233, train error 46.55,  test loss 1.357248, test error 49.25
# Epoch   900, train loss 1.360373, train error 46.30,  test loss 1.370011, test error 49.08
# Training model with  14 hidden variables
# Epoch     0, train loss 2.194667, train error 81.38,  test loss 2.144650, test error 81.05
# Epoch   100, train loss 1.469600, train error 50.78,  test loss 1.388073, test error 53.03
# Epoch   200, train loss 1.377073, train error 46.72,  test loss 1.323085, test error 49.60
# Epoch   300, train loss 1.336920, train error 44.78,  test loss 1.314596, test error 49.15
# Epoch   400, train loss 1.316835, train error 43.90,  test loss 1.337409, test error 49.38
# Epoch   500, train loss 1.296943, train error 42.42,  test loss 1.366733, test error 50.10
# Epoch   600, train loss 1.280621, train error 41.95,  test loss 1.371583, test error 49.60
# Epoch   700, train loss 1.270272, train error 41.30,  test loss 1.385789, test error 49.75
# Epoch   800, train loss 1.263548, train error 41.50,  test loss 1.391646, test error 49.78
# Epoch   900, train loss 1.262973, train error 41.38,  test loss 1.384981, test error 49.85
# Training model with  18 hidden variables
# Epoch     0, train loss 2.225110, train error 82.88,  test loss 2.199360, test error 81.25
# Epoch   100, train loss 1.350455, train error 45.40,  test loss 1.332690, test error 49.65
# Epoch   200, train loss 1.241395, train error 41.15,  test loss 1.329536, test error 49.40
# Epoch   300, train loss 1.193801, train error 39.47,  test loss 1.373369, test error 49.85
# Epoch   400, train loss 1.168565, train error 38.38,  test loss 1.408228, test error 49.97
# Epoch   500, train loss 1.153392, train error 37.55,  test loss 1.451087, test error 50.72
# Epoch   600, train loss 1.139332, train error 37.40,  test loss 1.469561, test error 50.38
# Epoch   700, train loss 1.134876, train error 37.05,  test loss 1.495966, test error 51.25
# Epoch   800, train loss 1.124145, train error 37.08,  test loss 1.505703, test error 51.35
# Epoch   900, train loss 1.127331, train error 36.88,  test loss 1.528393, test error 51.45
# Training model with  22 hidden variables
# Epoch     0, train loss 2.158108, train error 79.97,  test loss 2.133383, test error 80.10
# Epoch   100, train loss 1.253633, train error 42.62,  test loss 1.295459, test error 46.85
# Epoch   200, train loss 1.136932, train error 37.75,  test loss 1.378412, test error 49.28
# Epoch   300, train loss 1.082313, train error 37.15,  test loss 1.437264, test error 49.15
# Epoch   400, train loss 1.051150, train error 36.35,  test loss 1.507300, test error 49.78
# Epoch   500, train loss 1.035005, train error 35.62,  test loss 1.584170, test error 50.65
# Epoch   600, train loss 1.017294, train error 34.93,  test loss 1.597066, test error 50.67
# Epoch   700, train loss 0.994743, train error 33.88,  test loss 1.639990, test error 50.88
# Epoch   800, train loss 0.993837, train error 34.22,  test loss 1.681214, test error 50.88
# Epoch   900, train loss 0.989262, train error 34.22,  test loss 1.707333, test error 51.15
# Training model with  26 hidden variables
# Epoch     0, train loss 2.126987, train error 78.47,  test loss 2.099389, test error 79.35
# Epoch   100, train loss 1.199274, train error 39.75,  test loss 1.348731, test error 49.60
# Epoch   200, train loss 1.053841, train error 35.50,  test loss 1.461711, test error 49.97
# Epoch   300, train loss 1.007103, train error 34.43,  test loss 1.616657, test error 53.67
# Epoch   400, train loss 0.943379, train error 31.93,  test loss 1.679872, test error 53.35
# Epoch   500, train loss 0.907722, train error 31.30,  test loss 1.790696, test error 54.30
# Epoch   600, train loss 0.887770, train error 30.15,  test loss 1.850047, test error 54.15
# Epoch   700, train loss 0.868790, train error 29.70,  test loss 1.919981, test error 54.78
# Epoch   800, train loss 0.858417, train error 29.00,  test loss 1.983631, test error 54.47
# Epoch   900, train loss 0.839012, train error 28.22,  test loss 2.036462, test error 54.30
# Training model with  30 hidden variables
# Epoch     0, train loss 2.183506, train error 80.32,  test loss 2.169704, test error 79.35
# Epoch   100, train loss 1.126613, train error 37.50,  test loss 1.348858, test error 49.30
# Epoch   200, train loss 0.954297, train error 31.75,  test loss 1.492895, test error 50.38
# Epoch   300, train loss 0.841360, train error 27.95,  test loss 1.706716, test error 51.80
# Epoch   400, train loss 0.793610, train error 26.82,  test loss 1.914771, test error 52.03
# Epoch   500, train loss 0.757271, train error 26.22,  test loss 2.067294, test error 52.55
# Epoch   600, train loss 0.723346, train error 24.45,  test loss 2.239593, test error 53.35
# Epoch   700, train loss 0.682530, train error 22.65,  test loss 2.399241, test error 53.65
# Epoch   800, train loss 0.668645, train error 22.30,  test loss 2.566631, test error 54.25
# Epoch   900, train loss 0.661268, train error 22.75,  test loss 2.684368, test error 54.65
# Training model with  35 hidden variables
# Epoch     0, train loss 2.109844, train error 78.68,  test loss 2.049521, test error 76.70
# Epoch   100, train loss 1.024547, train error 33.15,  test loss 1.375424, test error 48.85
# Epoch   200, train loss 0.789102, train error 25.90,  test loss 1.694972, test error 51.35
# Epoch   300, train loss 0.661195, train error 22.43,  test loss 2.049566, test error 52.80
# Epoch   400, train loss 0.582339, train error 19.38,  test loss 2.399025, test error 53.20
# Epoch   500, train loss 0.537558, train error 17.70,  test loss 2.750707, test error 54.42
# Epoch   600, train loss 0.523574, train error 18.18,  test loss 3.120192, test error 54.78
# Epoch   700, train loss 0.485057, train error 16.40,  test loss 3.374014, test error 55.85
# Epoch   800, train loss 0.485377, train error 16.55,  test loss 3.656195, test error 56.00
# Epoch   900, train loss 0.476099, train error 16.47,  test loss 3.880574, test error 56.47
# Training model with  40 hidden variables
# Epoch     0, train loss 2.096662, train error 77.40,  test loss 2.039879, test error 77.57
# Epoch   100, train loss 0.904201, train error 29.40,  test loss 1.535875, test error 52.47
# Epoch   200, train loss 0.636004, train error 19.72,  test loss 1.974059, test error 52.97
# Epoch   300, train loss 0.480386, train error 14.97,  test loss 2.540308, test error 54.17
# Epoch   400, train loss 0.391476, train error 12.55,  test loss 3.285486, test error 56.00
# Epoch   500, train loss 0.340208, train error 11.75,  test loss 4.115138, test error 57.28
# Epoch   600, train loss 0.324762, train error 11.57,  test loss 4.875993, test error 57.28
# Epoch   700, train loss 0.277532, train error 9.90,  test loss 5.590190, test error 57.05
# Epoch   800, train loss 0.290569, train error 10.15,  test loss 6.241336, test error 58.10
# Epoch   900, train loss 0.270210, train error 9.68,  test loss 6.877118, test error 57.58
# Training model with  45 hidden variables
# Epoch     0, train loss 2.121642, train error 78.45,  test loss 2.099523, test error 79.88
# Epoch   100, train loss 0.866775, train error 27.93,  test loss 1.489784, test error 50.05
# Epoch   200, train loss 0.510501, train error 15.90,  test loss 2.127673, test error 53.40
# Epoch   300, train loss 0.311546, train error 9.28,  test loss 3.113196, test error 54.80
# Epoch   400, train loss 0.231441, train error 7.12,  test loss 4.270476, test error 56.47
# Epoch   500, train loss 0.268754, train error 10.32,  test loss 5.514260, test error 56.47
# Epoch   600, train loss 0.140347, train error 4.50,  test loss 6.456244, test error 56.45
# Epoch   700, train loss 0.171716, train error 6.07,  test loss 7.570666, test error 57.08
# Epoch   800, train loss 0.034345, train error 0.47,  test loss 8.346184, test error 56.12
# Epoch   900, train loss 0.006049, train error 0.00,  test loss 9.016887, test error 56.62
# Training model with  50 hidden variables
# Epoch     0, train loss 2.066794, train error 77.38,  test loss 2.025633, test error 75.93
# Epoch   100, train loss 0.756917, train error 23.72,  test loss 1.642307, test error 52.60
# Epoch   200, train loss 0.330952, train error 9.18,  test loss 2.720796, test error 55.67
# Epoch   300, train loss 0.146803, train error 3.28,  test loss 4.354732, test error 56.40
# Epoch   400, train loss 0.031125, train error 0.00,  test loss 5.943558, test error 56.53
# Epoch   500, train loss 0.014367, train error 0.00,  test loss 6.930180, test error 57.15
# Epoch   600, train loss 0.009145, train error 0.00,  test loss 7.562204, test error 56.97
# Epoch   700, train loss 0.006480, train error 0.00,  test loss 8.055521, test error 57.22
# Epoch   800, train loss 0.004962, train error 0.00,  test loss 8.428069, test error 56.95
# Epoch   900, train loss 0.004002, train error 0.00,  test loss 8.756720, test error 57.03
# Training model with  55 hidden variables
# Epoch     0, train loss 2.078306, train error 77.50,  test loss 2.036752, test error 75.62
# Epoch   100, train loss 0.659625, train error 20.53,  test loss 1.623172, test error 50.05
# Epoch   200, train loss 0.216141, train error 5.43,  test loss 2.855803, test error 53.33
# Epoch   300, train loss 0.036005, train error 0.00,  test loss 4.546602, test error 55.12
# Epoch   400, train loss 0.013562, train error 0.00,  test loss 5.495549, test error 54.50
# Epoch   500, train loss 0.007919, train error 0.00,  test loss 6.085282, test error 54.62
# Epoch   600, train loss 0.005487, train error 0.00,  test loss 6.503109, test error 54.75
# Epoch   700, train loss 0.004101, train error 0.00,  test loss 6.825783, test error 54.62
# Epoch   800, train loss 0.003259, train error 0.00,  test loss 7.095092, test error 54.67
# Epoch   900, train loss 0.002664, train error 0.00,  test loss 7.321146, test error 54.67
# Training model with  60 hidden variables
# Epoch     0, train loss 2.092684, train error 77.32,  test loss 2.055184, test error 77.82
# Epoch   100, train loss 0.486475, train error 14.15,  test loss 1.793910, test error 51.30
# Epoch   200, train loss 0.080204, train error 0.43,  test loss 3.403147, test error 52.97
# Epoch   300, train loss 0.017192, train error 0.00,  test loss 4.592407, test error 53.33
# Epoch   400, train loss 0.008747, train error 0.00,  test loss 5.228392, test error 53.92
# Epoch   500, train loss 0.005582, train error 0.00,  test loss 5.635403, test error 53.50
# Epoch   600, train loss 0.004005, train error 0.00,  test loss 5.943662, test error 53.70
# Epoch   700, train loss 0.003090, train error 0.00,  test loss 6.187308, test error 53.47
# Epoch   800, train loss 0.002489, train error 0.00,  test loss 6.396589, test error 53.65
# Epoch   900, train loss 0.002077, train error 0.00,  test loss 6.574511, test error 53.78
# Training model with  70 hidden variables
# Epoch     0, train loss 2.050072, train error 76.03,  test loss 1.978824, test error 75.60
# Epoch   100, train loss 0.335250, train error 8.15,  test loss 2.028842, test error 52.40
# Epoch   200, train loss 0.030504, train error 0.00,  test loss 3.709053, test error 53.50
# Epoch   300, train loss 0.010518, train error 0.00,  test loss 4.501895, test error 53.90
# Epoch   400, train loss 0.005929, train error 0.00,  test loss 4.936814, test error 53.85
# Epoch   500, train loss 0.003981, train error 0.00,  test loss 5.242846, test error 53.85
# Epoch   600, train loss 0.002956, train error 0.00,  test loss 5.476169, test error 53.88
# Epoch   700, train loss 0.002321, train error 0.00,  test loss 5.667083, test error 53.95
# Epoch   800, train loss 0.001895, train error 0.00,  test loss 5.827913, test error 54.05
# Epoch   900, train loss 0.001592, train error 0.00,  test loss 5.964383, test error 54.00
# Training model with  80 hidden variables
# Epoch     0, train loss 2.022434, train error 75.47,  test loss 1.981991, test error 75.40
# Epoch   100, train loss 0.269967, train error 5.62,  test loss 2.067999, test error 52.20
# Epoch   200, train loss 0.022834, train error 0.00,  test loss 3.444149, test error 52.85
# Epoch   300, train loss 0.008627, train error 0.00,  test loss 4.051084, test error 53.12
# Epoch   400, train loss 0.005038, train error 0.00,  test loss 4.411557, test error 53.22
# Epoch   500, train loss 0.003444, train error 0.00,  test loss 4.663730, test error 53.38
# Epoch   600, train loss 0.002578, train error 0.00,  test loss 4.861671, test error 53.45
# Epoch   700, train loss 0.002037, train error 0.00,  test loss 5.019053, test error 53.53
# Epoch   800, train loss 0.001671, train error 0.00,  test loss 5.151114, test error 53.53
# Epoch   900, train loss 0.001411, train error 0.00,  test loss 5.266059, test error 53.50
# Training model with  90 hidden variables
# Epoch     0, train loss 1.999554, train error 74.22,  test loss 1.940633, test error 73.68
# Epoch   100, train loss 0.127283, train error 0.88,  test loss 2.205051, test error 51.72
# Epoch   200, train loss 0.014447, train error 0.00,  test loss 3.247009, test error 51.85
# Epoch   300, train loss 0.006389, train error 0.00,  test loss 3.680654, test error 51.95
# Epoch   400, train loss 0.003941, train error 0.00,  test loss 3.948363, test error 51.70
# Epoch   500, train loss 0.002776, train error 0.00,  test loss 4.138994, test error 51.88
# Epoch   600, train loss 0.002116, train error 0.00,  test loss 4.287344, test error 51.72
# Epoch   700, train loss 0.001692, train error 0.00,  test loss 4.410632, test error 51.85
# Epoch   800, train loss 0.001402, train error 0.00,  test loss 4.512381, test error 51.75
# Epoch   900, train loss 0.001192, train error 0.00,  test loss 4.602678, test error 51.78
# Training model with 100 hidden variables
# Epoch     0, train loss 1.978674, train error 73.00,  test loss 1.908851, test error 73.30
# Epoch   100, train loss 0.087824, train error 0.15,  test loss 2.143688, test error 49.62
# Epoch   200, train loss 0.012256, train error 0.00,  test loss 2.951282, test error 50.53
# Epoch   300, train loss 0.005748, train error 0.00,  test loss 3.302486, test error 50.55
# Epoch   400, train loss 0.003571, train error 0.00,  test loss 3.523171, test error 50.72
# Epoch   500, train loss 0.002536, train error 0.00,  test loss 3.682615, test error 50.70
# Epoch   600, train loss 0.001943, train error 0.00,  test loss 3.807896, test error 50.60
# Epoch   700, train loss 0.001561, train error 0.00,  test loss 3.913496, test error 50.67
# Epoch   800, train loss 0.001297, train error 0.00,  test loss 4.000632, test error 50.65
# Epoch   900, train loss 0.001105, train error 0.00,  test loss 4.078176, test error 50.72
# Training model with 120 hidden variables
# Epoch     0, train loss 1.969477, train error 73.03,  test loss 1.905317, test error 74.20
# Epoch   100, train loss 0.049592, train error 0.00,  test loss 2.169823, test error 49.75
# Epoch   200, train loss 0.009625, train error 0.00,  test loss 2.765867, test error 49.78
# Epoch   300, train loss 0.004775, train error 0.00,  test loss 3.043236, test error 49.67
# Epoch   400, train loss 0.003050, train error 0.00,  test loss 3.220356, test error 49.70
# Epoch   500, train loss 0.002202, train error 0.00,  test loss 3.351493, test error 49.88
# Epoch   600, train loss 0.001701, train error 0.00,  test loss 3.454594, test error 49.80
# Epoch   700, train loss 0.001376, train error 0.00,  test loss 3.541048, test error 49.85
# Epoch   800, train loss 0.001148, train error 0.00,  test loss 3.614314, test error 49.75
# Epoch   900, train loss 0.000982, train error 0.00,  test loss 3.678164, test error 49.83
# Training model with 140 hidden variables
# Epoch     0, train loss 1.959156, train error 71.68,  test loss 1.898471, test error 71.32
# Epoch   100, train loss 0.033895, train error 0.00,  test loss 2.300690, test error 50.38
# Epoch   200, train loss 0.007838, train error 0.00,  test loss 2.813205, test error 50.50
# Epoch   300, train loss 0.004058, train error 0.00,  test loss 3.055424, test error 50.50
# Epoch   400, train loss 0.002647, train error 0.00,  test loss 3.210746, test error 50.42
# Epoch   500, train loss 0.001931, train error 0.00,  test loss 3.328324, test error 50.55
# Epoch   600, train loss 0.001503, train error 0.00,  test loss 3.422279, test error 50.58
# Epoch   700, train loss 0.001222, train error 0.00,  test loss 3.499740, test error 50.75
# Epoch   800, train loss 0.001024, train error 0.00,  test loss 3.565940, test error 50.70
# Epoch   900, train loss 0.000878, train error 0.00,  test loss 3.623450, test error 50.67
# Training model with 160 hidden variables
# Epoch     0, train loss 1.928575, train error 71.10,  test loss 1.856929, test error 72.30
# Epoch   100, train loss 0.029242, train error 0.00,  test loss 2.062358, test error 48.70
# Epoch   200, train loss 0.007244, train error 0.00,  test loss 2.468486, test error 48.70
# Epoch   300, train loss 0.003802, train error 0.00,  test loss 2.667772, test error 48.55
# Epoch   400, train loss 0.002496, train error 0.00,  test loss 2.799266, test error 48.58
# Epoch   500, train loss 0.001826, train error 0.00,  test loss 2.896829, test error 48.70
# Epoch   600, train loss 0.001425, train error 0.00,  test loss 2.975068, test error 48.80
# Epoch   700, train loss 0.001161, train error 0.00,  test loss 3.040488, test error 48.85
# Epoch   800, train loss 0.000974, train error 0.00,  test loss 3.095916, test error 48.62
# Epoch   900, train loss 0.000836, train error 0.00,  test loss 3.144494, test error 48.72
# Training model with 180 hidden variables
# Epoch     0, train loss 1.938265, train error 71.32,  test loss 1.874748, test error 72.20
# Epoch   100, train loss 0.024591, train error 0.00,  test loss 2.094122, test error 49.47
# Epoch   200, train loss 0.006656, train error 0.00,  test loss 2.447603, test error 49.42
# Epoch   300, train loss 0.003556, train error 0.00,  test loss 2.627341, test error 49.55
# Epoch   400, train loss 0.002355, train error 0.00,  test loss 2.747556, test error 49.62
# Epoch   500, train loss 0.001733, train error 0.00,  test loss 2.837760, test error 49.75
# Epoch   600, train loss 0.001357, train error 0.00,  test loss 2.909121, test error 49.72
# Epoch   700, train loss 0.001108, train error 0.00,  test loss 2.969512, test error 49.70
# Epoch   800, train loss 0.000932, train error 0.00,  test loss 3.021524, test error 49.62
# Epoch   900, train loss 0.000801, train error 0.00,  test loss 3.066535, test error 49.67
# Training model with 200 hidden variables
# Epoch     0, train loss 1.910483, train error 68.90,  test loss 1.832502, test error 70.50
# Epoch   100, train loss 0.022161, train error 0.00,  test loss 1.932694, test error 46.40
# Epoch   200, train loss 0.006144, train error 0.00,  test loss 2.236694, test error 46.12
# Epoch   300, train loss 0.003334, train error 0.00,  test loss 2.390330, test error 46.33
# Epoch   400, train loss 0.002219, train error 0.00,  test loss 2.494045, test error 46.25
# Epoch   500, train loss 0.001636, train error 0.00,  test loss 2.572547, test error 46.28
# Epoch   600, train loss 0.001283, train error 0.00,  test loss 2.635101, test error 46.15
# Epoch   700, train loss 0.001049, train error 0.00,  test loss 2.688122, test error 46.25
# Epoch   800, train loss 0.000883, train error 0.00,  test loss 2.733156, test error 46.35
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.772628, test error 46.28
# Training model with 250 hidden variables
# Epoch     0, train loss 1.886757, train error 68.75,  test loss 1.807911, test error 70.53
# Epoch   100, train loss 0.017239, train error 0.00,  test loss 1.895918, test error 47.78
# Epoch   200, train loss 0.005395, train error 0.00,  test loss 2.149421, test error 47.60
# Epoch   300, train loss 0.002993, train error 0.00,  test loss 2.281456, test error 47.33
# Epoch   400, train loss 0.002019, train error 0.00,  test loss 2.372060, test error 47.42
# Epoch   500, train loss 0.001503, train error 0.00,  test loss 2.441546, test error 47.53
# Epoch   600, train loss 0.001186, train error 0.00,  test loss 2.497182, test error 47.62
# Epoch   700, train loss 0.000974, train error 0.00,  test loss 2.543732, test error 47.70
# Epoch   800, train loss 0.000822, train error 0.00,  test loss 2.583463, test error 47.78
# Epoch   900, train loss 0.000709, train error 0.00,  test loss 2.619168, test error 47.78
# Training model with 300 hidden variables
# Epoch     0, train loss 1.891877, train error 69.03,  test loss 1.824154, test error 72.70
# Epoch   100, train loss 0.014540, train error 0.00,  test loss 1.873353, test error 47.00
# Epoch   200, train loss 0.004817, train error 0.00,  test loss 2.092912, test error 46.58
# Epoch   300, train loss 0.002733, train error 0.00,  test loss 2.212533, test error 46.45
# Epoch   400, train loss 0.001861, train error 0.00,  test loss 2.295033, test error 46.38
# Epoch   500, train loss 0.001393, train error 0.00,  test loss 2.358322, test error 46.50
# Epoch   600, train loss 0.001103, train error 0.00,  test loss 2.408964, test error 46.38
# Epoch   700, train loss 0.000908, train error 0.00,  test loss 2.452217, test error 46.55
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.489266, test error 46.45
# Epoch   900, train loss 0.000664, train error 0.00,  test loss 2.521466, test error 46.45
# Training model with 400 hidden variables
# Epoch     0, train loss 1.832627, train error 66.62,  test loss 1.771921, test error 68.72
# Epoch   100, train loss 0.011540, train error 0.00,  test loss 1.738948, test error 45.85
# Epoch   200, train loss 0.004118, train error 0.00,  test loss 1.908078, test error 45.53
# Epoch   300, train loss 0.002389, train error 0.00,  test loss 2.003441, test error 45.60
# Epoch   400, train loss 0.001646, train error 0.00,  test loss 2.069997, test error 45.35
# Epoch   500, train loss 0.001241, train error 0.00,  test loss 2.121043, test error 45.53
# Epoch   600, train loss 0.000989, train error 0.00,  test loss 2.162399, test error 45.60
# Epoch   700, train loss 0.000817, train error 0.00,  test loss 2.197021, test error 45.65
# Epoch   800, train loss 0.000693, train error 0.00,  test loss 2.227028, test error 45.62
# Epoch   900, train loss 0.000601, train error 0.00,  test loss 2.253323, test error 45.60

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
